# %% [markdown]
# # 🛠️ Advanced Tool Use with GitHub Models (Python)
#
# ## 📋 Learning Objectives
#
# This notebook demonstrates advanced tool integration patterns using the Microsoft Agent Framework with GitHub Models. You'll learn how to create, manage, and orchestrate multiple tools to build sophisticated agent capabilities.
#
# **What You'll Master:**
# - 🔧 **Multi-Tool Architecture**: Building agents with multiple specialized tools
# - 🎯 **Tool Selection Logic**: How agents choose the right tool for each task
# - 📊 **Data Processing Tools**: Creating tools that handle different data types
# - 🔗 **Tool Composition**: Combining tools for complex workflows
#
# ## 🎯 Key Tool Patterns
#
# ### Tool Design Principles
# - **Single Responsibility**: Each tool has a clear, focused purpose
# - **Type Safety**: Strong typing for reliable tool execution
# - **Error Handling**: Graceful failure and recovery patterns
# - **Composability**: Tools that work well together
#
# ### Advanced Tool Features
# - **Context Awareness**: Tools that understand conversation context
# - **Data Validation**: Input sanitization and output validation
# - **Performance Optimization**: efficient tool execution patterns
# - **Extensibility**: Easy addition of new tool capabilities
#
# ## 🔧 Technical Architecture
#
# ### Core Components
# - **Microsoft Agent Framework**: Python implementation with advanced tool support
# - **GitHub Models Integration**: High-performance language model access
# - **Tool Registry System**: Organized management of agent capabilities
# - **Error Recovery Patterns**: Robust handling of tool execution failures
#
# ### Tool Integration Flow
# ```python
# User Request → Agent Analysis → Tool Selection → Tool Execution → Response Synthesis
# ```
#
# ## 🛠️ Tool Categories Demonstrated
#
# ### 1. **Data Generation Tools**
# - Random destination generator
# - Weather information provider
# - Travel cost calculator
# - Activity recommendation engine
#
# ### 2. **Processing Tools**
# - Text formatting and validation
# - Data transformation utilities
# - Content analysis functions
# - Response enhancement tools
#
# ### 3. **Integration Tools**
# - External API connectors
# - File system operations
# - Database query interfaces
# - Web scraping utilities
#
# ## ⚙️ Prerequisites & Setup
#
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Optional APIs:**
# - Weather service API key (for weather tools)
# - Currency conversion API access
# - Travel information service credentials
#
# ## 🎨 Design Patterns
#
# ### Tool Factory Pattern
# - Centralized tool creation and configuration
# - Consistent tool interface design
# - Easy tool registration and discovery
#
# ### Command Pattern
# - Encapsulated tool execution logic
# - Undo/redo functionality for complex operations
# - Audit logging for tool usage
#
# ### Observer Pattern
# - Tool execution monitoring
# - Performance metrics collection
# - Error reporting and alerting
#
# ## 🚀 Best Practices
#
# - **Tool Documentation**: Clear descriptions for agent understanding
# - **Input Validation**: Robust parameter checking and sanitization
# - **Output Formatting**: Consistent, parseable tool responses
# - **Error Messages**: Helpful error information for debugging
# - **Performance**: Optimized tool execution for responsiveness
#
# Ready to build agents with powerful tool capabilities? Let's create something amazing! ⚡

# %%
# %pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (1.0.0b260116)
# Collecting agent-framework-core
#   Using cached agent_framework_core-1.0.0b260130-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (2.12.5)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (2.15.0)
# Requirement already satisfied: azure-identity<2,>=1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp<2,>=1.24.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.25.0)
# Requirement already satisfied: packaging>=24.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.38.0)
# Requirement already satisfied: cryptography>=2.5 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.21)
# Requirement already satisfied: pywin32>=310 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: requests>=2.21.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.23)
# Requirement already satisfied: certifi in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: colorama in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\notebooks\ai-agents-for-beginners\venv\lib\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.1)
# Using cached agent_framework_core-1.0.0b260130-py3-none-any.whl (348 kB)
# Installing collected packages: agent-framework-core
#   Attempting uninstall: agent-framework-core
#     Found existing installation: agent-framework-core 1.0.0b260116
#     Uninstalling agent-framework-core-1.0.0b260116:
#       Successfully uninstalled agent-framework-core-1.0.0b260116
# Successfully installed agent-framework-core-1.0.0b260130
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002130C346CF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/agent-framework-core/
#
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# � Import core dependencies for Agent Framework and tool integration
# This sets up the essential libraries for building intelligent agents with tool capabilities

import asyncio
import os
import json

from dotenv import load_dotenv  # For loading environment variables securely
from random import randint

# These are the core components for building tool-enabled agents
from agent_framework import ChatAgent           # Main agent class
from agent_framework.openai import OpenAIChatClient  # OpenAI-compatible client

# %%
load_dotenv()
# Out:
# True

# %%
# 🔑 Environment variables verification
# Ensure all required GitHub Models credentials are properly configured
print("GITHUB_ENDPOINT:", os.environ.get("GITHUB_ENDPOINT"))
print("GITHUB_TOKEN:", "***" if os.environ.get("GITHUB_TOKEN") else "Not set")
print("GITHUB_MODEL_ID:", os.environ.get("GITHUB_MODEL_ID"))
# Out:
# GITHUB_ENDPOINT: https://models.inference.ai.azure.com
# GITHUB_TOKEN: ***
# GITHUB_MODEL_ID: gpt-4o-mini

# %%
# 🧪 Test GitHub Models connectivity
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"),
    model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🛠️ Define travel planning tools for agent integration
# These functions provide specific capabilities that the agent can invoke dynamically

def get_random_destination() -> str:
    """
    🎲 Random destination generator tool
    Returns a randomly selected travel destination from curated list
    Useful when customers need inspiration for their next vacation
    """
    destinations = [
        "Paris, France",
        "Tokyo, Japan", 
        "New York City, USA",
        "London, England",
        "Rome, Italy",
        "Sydney, Australia",
        "Dubai, UAE",
        "Barcelona, Spain",
        "Bangkok, Thailand",
        "Amsterdam, Netherlands",
        "Istanbul, Turkey",
        "Prague, Czech Republic",
        "Santorini, Greece",
        "Reykjavik, Iceland",
        "Marrakech, Morocco",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # 🎯 Return random selection from the curated destination list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Initialize GitHub Models chat client for agent communication
# Creates the primary interface between the agent and the language model
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"),
    model_id=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Configure travel agent identity and behavioral instructions
# Define the agent's personality, capabilities, and operational guidelines

AGENT_NAME = "TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers at random destinations
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# How about a day trip to Rome, Italy? Here’s a plan to make the most of your time in this beautiful city:
#
# ### Morning
# - **Breakfast:** Start your day with a traditional Italian breakfast at a café. Try a cornetto (Italian croissant) with an espresso.
# - **Colosseum:** Visit the iconic Colosseum. Make sure to book your tickets in advance to avoid long lines.
#
# ### Midday
# - **Roman Forum:** After the Colosseum, explore the nearby Roman Forum, the heart of ancient Rome.
# - **Lunch:** Enjoy lunch at a local trattoria. Consider trying a classic Roman dish like Cacio e Pepe or Carbonara.
#
# ### Afternoon
# - **Vatican City:** Head over to Vatican City to see St. Peter's Basilica. If time permits, you can also visit the Vatican Museums and see the Sistine Chapel.
# - **Piazza Navona:** Stroll to Piazza Navona, famous for its beautiful fountains and vibrant atmosphere.
#
# ### Evening
# - **Dinner:** Have dinner in Trastevere, a charming neighborhood filled with restaurants and bars. Try a traditional Roman pizza.
# - **Gelato:** End your day with some authentic Italian gelato while walking along the Tiber River.
#
# ### Tips:
# - Wear comfortable shoes as you will be walking a lot.
# - Keep an eye on the time to ensure you can see all the attractions you want.
# - Consider using public transport or walking to soak in the sights.
#
# Enjoy your day in Rome!
