# %% [markdown]
# # 🔍 Exploring Agentic Frameworks - Basic Agent (Python)
#
# ## 📋 Learning Objectives
#
# This notebook explores the fundamental concepts of the Microsoft Agent Framework through a basic agent implementation. You'll learn core agentic patterns and understand how intelligent agents work under the hood.
#
# **What You'll Discover:**
# - 🏗️ **Agent Architecture**: Understanding the basic structure of AI agents
# - 🛠️ **Tool Integration**: How agents use external functions to extend capabilities
# - 💬 **Conversation Flow**: Managing multi-turn conversations and context
# - 🔧 **Configuration Patterns**: Best practices for agent setup and management
#
# ## 🎯 Key Concepts Covered
#
# ### Agentic Framework Principles
# - **Autonomy**: How agents make independent decisions
# - **Reactivity**: Responding to environmental changes and user inputs
# - **Proactivity**: Taking initiative based on goals and context
# - **Social Ability**: Interacting through natural language
#
# ### Technical Components
# - **ChatAgent**: Core agent orchestration and conversation management
# - **Tool Functions**: Extending agent capabilities with custom functions
# - **OpenAI Integration**: Leveraging language models through standardized APIs
# - **Environment Management**: Secure configuration and credential handling
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core  -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🔧 Technical Stack
#
# **Core Technologies:**
# - Microsoft Agent Framework (Python)
# - GitHub Models API integration
# - OpenAI-compatible client patterns
# - Environment-based configuration
#
# **Agent Capabilities:**
# - Natural language understanding and generation
# - Function calling and tool usage
# - Context-aware responses
# - Extensible architecture
#
# ## 📚 Framework Comparison
#
# This example demonstrates the Microsoft Agent Framework approach compared to other agentic frameworks:
#
# | Feature | Microsoft Agent Framework | Other Frameworks |
# |---------|-------------------------|------------------|
# | **Integration** | Native Microsoft ecosystem | Varied compatibility |
# | **Simplicity** | Clean, intuitive API | Often complex setup |
# | **Extensibility** | Easy tool integration | Framework-dependent |
# | **Enterprise Ready** | Built for production | Varies by framework |
#
# ## 🚀 Getting Started
#
# Follow the cells below to build your first basic agent and understand foundational agentic concepts!

# %%
! pip install agent-framework-core  -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: agent-framework-core in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.0.0b260116)
# Collecting agent-framework-core
#   Downloading agent_framework_core-1.0.0b260130-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (2.12.5)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (2.15.0)
# Requirement already satisfied: azure-identity<2,>=1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp<2,>=1.24.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.25.0)
# Requirement already satisfied: packaging>=24.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.38.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.21)
# Requirement already satisfied: pywin32>=310 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.1.2)
# Requirement already satisfied: starlette>=0.27 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.51.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3,>=2->agent-framework-core) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: requests>=2.21.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.23)
# Requirement already satisfied: certifi in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: colorama in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.0)
# Downloading agent_framework_core-1.0.0b260130-py3-none-any.whl (348 kB)
# Installing collected packages: agent-framework-core
#   Attempting uninstall: agent-framework-core
#     Found existing installation: agent-framework-core 1.0.0b260116
#     Uninstalling agent-framework-core-1.0.0b260116:
#       Successfully uninstalled agent-framework-core-1.0.0b260116
# Successfully installed agent-framework-core-1.0.0b260130
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/agent-framework-core/
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: C:\Users\ahmed\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections

from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model identifier (e.g., gpt-4o-mini)
)

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = ChatAgent(
    chat_client=openai_chat_client,  # The AI model client for generating responses
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # System prompt defining agent behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# For your day trip, let's plan an exciting adventure in Bali, Indonesia! Here's a suggested itinerary:
#
# ### Morning:
# - **Breakfast at a Local Café**: Start your day with traditional Balinese breakfast, featuring Nasi Goreng (fried rice) or a fruit smoothie bowl.
# - **Visit to Ubud Monkey Forest**: Explore this beautiful sanctuary home to hundreds of playful monkeys and ancient temples.
#
# ### Midday:
# - **Lunch in Ubud**: Enjoy a healthy lunch at a local café, perhaps trying a delicious Bali bowl with fresh ingredients.
# - **Tegallalang Rice Terraces**: After lunch, head to these stunning rice terraces that offer beautiful views and photo opportunities. Take a short walk through the lush landscapes.
#
# ### Afternoon:
# - **Visit to Tirta Empul Temple**: Experience the sacred water temple, where visitors can participate in a purification ritual in the holy springs.
# - **Coffee Tasting**: Stop by a local coffee plantation to taste some authentic Balinese coffee, including the famous Kopi Luwak.
#
# ### Evening:
# - **Dinner at Jimbaran Beach**: Head to the beach for a seafood dinner right by the water. Many restaurants offer fresh grilled seafood with a beautiful sunset view.
# - **Relax on the Beach**: Wind down your day by relaxing on the beach, enjoying the sound of waves and the cool breeze.
#
# ### Optional Night Activity:
# - **Cultural Dance Performance**: If you're up for it, check out a traditional Balinese dance performance in Ubud or at a nearby location.
#
# This day trip will give you a taste of Bali's culture, beauty, and delicious food. Enjoy your adventure!

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# For your next vacation, how about a trip to Barcelona, Spain? Here's a suggested itinerary for an exciting day there:
#
# ### Morning:
# - **Breakfast at a Local Café**: Start your day with a traditional Spanish breakfast of "tostada con tomate" (toasted bread with tomato) and a café con leche (coffee with milk).
# - **Visit La Sagrada Familia**: Explore the iconic basilica designed by Antoni Gaudí. Make sure to book tickets in advance to skip the lines.
#
# ### Midday:
# - **Lunch in the Gothic Quarter**: Enjoy a leisurely lunch at a tapas bar in the charming Gothic Quarter. Try different tapas like patatas bravas, jamón ibérico, and pan con ajo.
# - **Stroll through the Gothic Quarter**: After lunch, wander through the narrow streets, visit the Barcelona Cathedral, and enjoy the medieval architecture.
#
# ### Afternoon:
# - **Park Güell**: Head to another of Gaudí's masterpieces, Park Güell, where you can marvel at the colorful mosaics and unique structures. The park provides great views of the city.
# - **Shopping at Passeig de Gràcia**: Explore some of the most famous designer shops and boutiques. Don’t miss the beautiful architecture along the way.
#
# ### Evening:
# - **Dinner at a Local Restaurant**: Indulge in a traditional Catalan meal. Try dishes like fideuà (seafood noodle dish) or a classic paella at a local restaurant.
# - **Evening Stroll Along La Barceloneta**: Take a relaxing walk along the beach promenade, enjoying the sunset and atmosphere.
#
# ### Optional Night Activity:
# - **Flamenco Show**: Experience a passionate Flamenco performance to get a taste of Spanish music and dance culture.
#
# This day in Barcelona will be filled with art, culture, delicious food, and vibrant atmosphere. Enjoy your trip!
