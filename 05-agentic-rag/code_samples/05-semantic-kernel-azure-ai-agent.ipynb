# %% [markdown]
# # RAG Using Azure AI Agent Service & Semantic Kernel
#
# This code snippet demonstrates how to create and manage an Azure AI agent for retrieval-augmented generation (RAG) using the `Azure AI Agent Service` and `Semantic Kernel`. The agent processes user queries based on the retrieved context and provides accurate responses accordingly.

# %% [markdown]
# ## Initializing the Environment

# %% [markdown]
# SQLite Version Fix
# If you encounter the error:
# ```
# RuntimeError: Your system has an unsupported version of sqlite3. Chroma requires sqlite3 >= 3.35.0
# ```
#
# Uncomment this code block at the start of your notebook:

# %%
# %pip install pysqlite3-binary
# __import__('pysqlite3')
# import sys
# sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
! pip install azure-ai-projects semantic-kernel[azure] azure-identity
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting azure-ai-projects
#   Using cached azure_ai_projects-1.0.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: azure-identity in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.25.1)
# Collecting semantic-kernel[azure]
#   Using cached semantic_kernel-1.39.3-py3-none-any.whl.metadata (13 kB)
# Collecting isodate>=0.6.1 (from azure-ai-projects)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-ai-projects) (1.38.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-ai-projects) (4.15.0)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects)
#   Using cached azure_storage_blob-12.28.0-py3-none-any.whl.metadata (26 kB)
# Collecting azure-ai-agents>=1.0.0 (from azure-ai-projects)
#   Using cached azure_ai_agents-1.1.0-py3-none-any.whl.metadata (52 kB)
#   Using cached azure_ai_agents-1.2.0b6-py3-none-any.whl.metadata (74 kB)
# Collecting aiohttp~=3.8 (from semantic-kernel[azure])
#   Using cached aiohttp-3.13.3-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting cloudevents~=1.0 (from semantic-kernel[azure])
#   Using cached cloudevents-1.12.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 (from semantic-kernel[azure])
#   Using cached pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: pydantic-settings~=2.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from semantic-kernel[azure]) (2.12.0)
# Collecting defusedxml~=0.7 (from semantic-kernel[azure])
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting numpy>=1.26.0 (from semantic-kernel[azure])
#   Using cached numpy-2.4.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting openai<2,>=1.98.0 (from semantic-kernel[azure])
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel[azure])
#   Using cached openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<16,>=13 (from semantic-kernel[azure])
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting aiortc>=1.9.0 (from semantic-kernel[azure])
#   Using cached aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from semantic-kernel[azure]) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from semantic-kernel[azure]) (1.39.1)
# Collecting prance<25.4.9,>=23.6.21 (from semantic-kernel[azure])
#   Using cached prance-25.4.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel[azure])
#   Using cached pybars4-0.9.13-py3-none-any.whl
# Requirement already satisfied: jinja2~=3.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from semantic-kernel[azure]) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from semantic-kernel[azure]) (1.6.0)
# Collecting scipy>=1.15.1 (from semantic-kernel[azure])
#   Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting protobuf (from semantic-kernel[azure])
#   Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting azure-ai-inference>=1.0.0b6 (from semantic-kernel[azure])
#   Using cached azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Collecting azure-core-tracing-opentelemetry>=1.0.0b11 (from semantic-kernel[azure])
#   Using cached azure_core_tracing_opentelemetry-1.0.0b12-py3-none-any.whl.metadata (11 kB)
# Collecting azure-search-documents>=11.6.0b4 (from semantic-kernel[azure])
#   Using cached azure_search_documents-11.7.0b2-py3-none-any.whl.metadata (22 kB)
# Collecting azure-cosmos~=4.7 (from semantic-kernel[azure])
#   Using cached azure_cosmos-4.14.6-py3-none-any.whl.metadata (106 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp~=3.8->semantic-kernel[azure])
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp~=3.8->semantic-kernel[azure])
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp~=3.8->semantic-kernel[azure]) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.8->semantic-kernel[azure])
#   Using cached frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.8->semantic-kernel[azure])
#   Using cached multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.8->semantic-kernel[azure])
#   Using cached propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.8->semantic-kernel[azure])
#   Using cached yarl-1.22.0-cp313-cp313-win_amd64.whl.metadata (77 kB)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel[azure])
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from deprecation<3.0,>=2.0->cloudevents~=1.0->semantic-kernel[azure]) (25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2~=3.1->semantic-kernel[azure]) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<2,>=1.98.0->semantic-kernel[azure]) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<2,>=1.98.0->semantic-kernel[azure]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<2,>=1.98.0->semantic-kernel[azure]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<2,>=1.98.0->semantic-kernel[azure]) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<2,>=1.98.0->semantic-kernel[azure]) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<2,>=1.98.0->semantic-kernel[azure]) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio<5,>=3.5.0->openai<2,>=1.98.0->semantic-kernel[azure]) (3.11)
# Requirement already satisfied: certifi in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->openai<2,>=1.98.0->semantic-kernel[azure]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->openai<2,>=1.98.0->semantic-kernel[azure]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2,>=1.98.0->semantic-kernel[azure]) (0.16.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[azure]) (4.26.0)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (0.30.0)
# Collecting PyYAML>=5.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (2.32.5)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel[azure])
#   Using cached lazy_object_proxy-1.12.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-api~=1.24->semantic-kernel[azure]) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel[azure]) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel[azure]) (0.60b1)
# Collecting chardet>=5.2 (from prance<25.4.9,>=23.6.21->semantic-kernel[azure])
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.18.10 (from prance<25.4.9,>=23.6.21->semantic-kernel[azure])
#   Using cached ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel[azure])
#   Using cached pymeta3-0.5.1-py3-none-any.whl
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel[azure]) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel[azure])
#   Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel[azure]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic-settings~=2.0->semantic-kernel[azure]) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (2.6.3)
# Requirement already satisfied: cryptography>=2.5 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from azure-identity) (1.3.1)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached aioice-0.10.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<17.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached av-16.1.0-cp313-cp313-win_amd64.whl.metadata (4.7 kB)
# Collecting google-crc32c>=1.1 (from aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached google_crc32c-1.8.0-cp313-cp313-win_amd64.whl.metadata (1.8 kB)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached pylibsrtp-1.0.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached pyopenssl-25.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel[azure])
#   Using cached ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting azure-common>=1.1 (from azure-search-documents>=11.6.0b4->semantic-kernel[azure])
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: colorama in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm>4->openai<2,>=1.98.0->semantic-kernel[azure]) (0.4.6)
# Requirement already satisfied: six in c:\users\ahmed\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rfc3339-validator->openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel[azure]) (1.17.0)
# Using cached azure_ai_projects-1.0.0-py3-none-any.whl (115 kB)
# Using cached semantic_kernel-1.39.3-py3-none-any.whl (913 kB)
# Using cached aiohttp-3.13.3-cp313-cp313-win_amd64.whl (453 kB)
# Using cached azure_cosmos-4.14.6-py3-none-any.whl (395 kB)
# Using cached cloudevents-1.12.0-py3-none-any.whl (55 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Using cached openapi_core-0.19.5-py3-none-any.whl (106 kB)
# Using cached jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Using cached openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Using cached openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Using cached lazy_object_proxy-1.12.0-cp313-cp313-win_amd64.whl (26 kB)
# Using cached pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Using cached prance-25.4.8.0-py3-none-any.whl (36 kB)
# Using cached pydantic-2.11.10-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached werkzeug-3.1.1-py3-none-any.whl (224 kB)
# Using cached yarl-1.22.0-cp313-cp313-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiortc-1.14.0-py3-none-any.whl (93 kB)
# Using cached aioice-0.10.2-py3-none-any.whl (24 kB)
# Using cached av-16.1.0-cp313-cp313-win_amd64.whl (31.7 MB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached azure_ai_agents-1.2.0b6-py3-none-any.whl (217 kB)
# Using cached azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
# Using cached azure_core_tracing_opentelemetry-1.0.0b12-py3-none-any.whl (11 kB)
# Using cached azure_search_documents-11.7.0b2-py3-none-any.whl (432 kB)
# Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Using cached azure_storage_blob-12.28.0-py3-none-any.whl (431 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Using cached frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Using cached google_crc32c-1.8.0-cp313-cp313-win_amd64.whl (34 kB)
# Using cached ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached numpy-2.4.2-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Using cached pyee-13.0.0-py3-none-any.whl (15 kB)
# Using cached pylibsrtp-1.0.0-cp310-abi3-win_amd64.whl (1.6 MB)
# Using cached pyopenssl-25.3.0-py3-none-any.whl (57 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Using cached ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
# Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl (36.3 MB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Installing collected packages: PyMeta3, parse, ifaddr, azure-common, werkzeug, websockets, ruamel.yaml, rfc3339-validator, referencing, PyYAML, pyee, pydantic-core, pybars4, protobuf, propcache, pathable, numpy, multidict, more-itertools, lazy-object-proxy, isodate, google-crc32c, frozenlist, dnspython, deprecation, defusedxml, chardet, av, aiohappyeyeballs, yarl, scipy, pylibsrtp, pydantic, prance, jsonschema-path, cloudevents, aiosignal, aioice, pyopenssl, openai, azure-storage-blob, azure-search-documents, azure-cosmos, azure-core-tracing-opentelemetry, azure-ai-inference, azure-ai-agents, aiohttp, openapi-schema-validator, azure-ai-projects, aiortc, openapi-spec-validator, openapi_core, semantic-kernel
#
#   Attempting uninstall: werkzeug
#
#     Found existing installation: Werkzeug 3.1.3
#
#     Uninstalling Werkzeug-3.1.3:
#
#    --- ------------------------------------  4/53 [werkzeug]
#       Successfully uninstalled Werkzeug-3.1.3
#    --- ------------------------------------  4/53 [werkzeug]
#    --- ------------------------------------  4/53 [werkzeug]
#   Attempting uninstall: websockets
#    --- ------------------------------------  4/53 [werkzeug]
#     Found existing installation: websockets 16.0
#    --- ------------------------------------  4/53 [werkzeug]
#     Uninstalling websockets-16.0:
#    --- ------------------------------------  4/53 [werkzeug]
#       Successfully uninstalled websockets-16.0
#    --- ------------------------------------  4/53 [werkzeug]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    --- ------------------------------------  5/53 [websockets]
#    ---- -----------------------------------  6/53 [ruamel.yaml]
#   Attempting uninstall: referencing
#    ---- -----------------------------------  6/53 [ruamel.yaml]
#     Found existing installation: referencing 0.37.0
#    ---- -----------------------------------  6/53 [ruamel.yaml]
#     Uninstalling referencing-0.37.0:
#    ---- -----------------------------------  6/53 [ruamel.yaml]
#       Successfully uninstalled referencing-0.37.0
#    ---- -----------------------------------  6/53 [ruamel.yaml]
#    ------ ---------------------------------  9/53 [PyYAML]
#   Attempting uninstall: pydantic-core
#    ------ ---------------------------------  9/53 [PyYAML]
#     Found existing installation: pydantic_core 2.41.5
#    ------ ---------------------------------  9/53 [PyYAML]
#     Uninstalling pydantic_core-2.41.5:
#    ------ ---------------------------------  9/53 [PyYAML]
#       Successfully uninstalled pydantic_core-2.41.5
#    ------ ---------------------------------  9/53 [PyYAML]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    -------- ------------------------------- 11/53 [pydantic-core]
#    --------- ------------------------------ 12/53 [pybars4]
#    --------- ------------------------------ 13/53 [protobuf]
#    ---------- ----------------------------- 14/53 [propcache]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 16/53 [numpy]
#    ------------ --------------------------- 17/53 [multidict]
#    ----------------- ---------------------- 23/53 [dnspython]
#    ----------------- ---------------------- 23/53 [dnspython]
#    ------------------- -------------------- 26/53 [chardet]
#    -------------------- ------------------- 27/53 [av]
#    -------------------- ------------------- 27/53 [av]
#    -------------------- ------------------- 27/53 [av]
#    --------------------- ------------------ 29/53 [yarl]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#    ---------------------- ----------------- 30/53 [scipy]
#   Attempting uninstall: pydantic
#    ---------------------- ----------------- 30/53 [scipy]
#     Found existing installation: pydantic 2.12.5
#    ---------------------- ----------------- 30/53 [scipy]
#    ------------------------ --------------- 32/53 [pydantic]
#     Uninstalling pydantic-2.12.5:
#    ------------------------ --------------- 32/53 [pydantic]
#       Successfully uninstalled pydantic-2.12.5
#    ------------------------ --------------- 32/53 [pydantic]
#    ------------------------ --------------- 32/53 [pydantic]
#    ------------------------ --------------- 32/53 [pydantic]
#    --------------------------- ------------ 37/53 [aioice]
#   Attempting uninstall: openai
#    --------------------------- ------------ 37/53 [aioice]
#     Found existing installation: openai 2.15.0
#    --------------------------- ------------ 37/53 [aioice]
#    ----------------------------- ---------- 39/53 [openai]
#     Uninstalling openai-2.15.0:
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#       Successfully uninstalled openai-2.15.0
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ----------------------------- ---------- 39/53 [openai]
#    ------------------------------ --------- 40/53 [azure-storage-blob]
#    ------------------------------ --------- 40/53 [azure-storage-blob]
#    ------------------------------ --------- 41/53 [azure-search-documents]
#    ------------------------------ --------- 41/53 [azure-search-documents]
#    ------------------------------- -------- 42/53 [azure-cosmos]
#    ------------------------------- -------- 42/53 [azure-cosmos]
#    --------------------------------- ------ 44/53 [azure-ai-inference]
#    --------------------------------- ------ 45/53 [azure-ai-agents]
#    ---------------------------------- ----- 46/53 [aiohttp]
#    ------------------------------------ --- 48/53 [azure-ai-projects]
#    -------------------------------------- - 51/53 [openapi_core]
#    -------------------------------------- - 51/53 [openapi_core]
#    ---------------------------------------  52/53 [semantic-kernel]
#    ---------------------------------------  52/53 [semantic-kernel]
#    ---------------------------------------  52/53 [semantic-kernel]
#    ---------------------------------------  52/53 [semantic-kernel]
#    ---------------------------------------  52/53 [semantic-kernel]
#    ---------------------------------------  52/53 [semantic-kernel]
#    ---------------------------------------- 53/53 [semantic-kernel]
#
# Successfully installed PyMeta3-0.5.1 PyYAML-6.0.3 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aioice-0.10.2 aiortc-1.14.0 aiosignal-1.4.0 av-16.1.0 azure-ai-agents-1.2.0b6 azure-ai-inference-1.0.0b9 azure-ai-projects-1.0.0 azure-common-1.1.28 azure-core-tracing-opentelemetry-1.0.0b12 azure-cosmos-4.14.6 azure-search-documents-11.7.0b2 azure-storage-blob-12.28.0 chardet-5.2.0 cloudevents-1.12.0 defusedxml-0.7.1 deprecation-2.1.0 dnspython-2.8.0 frozenlist-1.8.0 google-crc32c-1.8.0 ifaddr-0.2.0 isodate-0.7.2 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 more-itertools-10.8.0 multidict-6.7.1 numpy-2.4.2 openai-1.109.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 openapi_core-0.19.5 parse-1.20.2 pathable-0.4.4 prance-25.4.8.0 propcache-0.4.1 protobuf-6.33.5 pybars4-0.9.13 pydantic-2.11.10 pydantic-core-2.33.2 pyee-13.0.0 pylibsrtp-1.0.0 pyopenssl-25.3.0 referencing-0.36.2 rfc3339-validator-0.1.4 ruamel.yaml-0.19.1 scipy-1.17.0 semantic-kernel-1.39.3 websockets-15.0.1 werkzeug-3.1.1 yarl-1.22.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ahmed\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\~ebsockets'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ahmed\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\~ydantic_core'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: C:\Users\ahmed\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importing Packages
# The following code imports the necessary packages:

# %%
# Azure imports for project client and credentials
from azure.ai.projects.models import FileSearchTool, OpenAIFile, VectorStore
from azure.identity.aio import DefaultAzureCredential

# Semantic Kernel imports
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentThread
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Azure imports for project client and credentials
# ----> 2 from azure.ai.projects.models import FileSearchTool, OpenAIFile, VectorStore
#       3 from azure.identity.aio import DefaultAzureCredential
#       5 # Semantic Kernel imports
#
# ImportError: cannot import name 'FileSearchTool' from 'azure.ai.projects.models' (C:\Users\ahmed\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\azure\ai\projects\models\__init__.py)

# %% [markdown]
# # Retrieval-Augmented Generation with Semantic Kernel & Azure AI Agent Service
#
# This sample demonstrates how to use the **Azure AI Agent Service** to perform **Retrieval-Augmented Generation (RAG)** by combining a language model with domain-specific context from an uploaded document.
#
# ### How It Works
#
# 1. **Document Upload**: A markdown file (document.md) containing information (Contoso's travel insurance policy) is uploaded to the agent service.
#
# 2. **Vector Store Creation**: The document is indexed into a vector store to enable semantic search over its contents.
#
# 3. **Agent Configuration**: An agent is instantiated using the `gpt-4o` model with the following strict instructions:
#    - Only answer questions based on retrieved content from the document.
#    - Decline to answer if the question is out of scope.
#
# 4. **File Search Tool Integration**: The `FileSearchTool` is registered with the agent, enabling the model to search and retrieve relevant snippets from the indexed document during inference.
#
# 5. **User Interaction**: Users can ask questions. If relevant information is found in the document, the agent generates a grounded answer.
#    If not, the agent explicitly responds that the document does not contain sufficient information.

# %% [markdown]
# ### Main Function

# %% [markdown]
# Make sure to first run `az login` using the Azure CLI so that the proper authentication context is provided while using the `DefaultAzureCredential`. The Azure AI Agent Service does not use API keys.

# %%
async def main():
    async with (
        DefaultAzureCredential() as creds,
        AzureAIAgent.create_client(credential=creds) as client,
    ):
        file: OpenAIFile = await client.agents.upload_file_and_poll(file_path="document.md", purpose="assistants")
        vector_store: VectorStore = await client.agents.create_vector_store_and_poll(
            file_ids=[file.id], name="my_vectorstore"
        )

        # Define agent name and instructions tailored for RAG.
        AGENT_NAME = "RAGAgent"
        AGENT_INSTRUCTIONS = """
        You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

        - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
        "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
        - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
        - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
        - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
        - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

        You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
        """

        
        # Create file search tool with uploaded resources
        file_search = FileSearchTool(vector_store_ids=[vector_store.id])

        # 3. Create an agent on the Azure AI agent service with the file search tool
        agent_definition = await client.agents.create_agent(
            model="gpt-4o",  # This model should match your Azure OpenAI deployment.
            name=AGENT_NAME,
            instructions=AGENT_INSTRUCTIONS,
            tools=file_search.definitions,
            tool_resources=file_search.resources,
        )
        
        # Create the Azure AI Agent using the client and definition.
        agent = AzureAIAgent(
            client=client,
            definition=agent_definition,
        )
        
        # Create a thread to hold the conversation
        # If no thread is provided, a new thread will be
        # created and returned with the initial response
        thread: AzureAIAgentThread | None = None
        
        # Example user queries.
        user_inputs = [
            "Can you explain Contoso's travel insurance coverage?",  # Relevant context.
            "What is a Neural Network?"  # No relevant context from the document. Will not contain a source annotation.
        ]
        
        try:
            for user_input in user_inputs:
                print(f"# User: '{user_input}'")
                # Invoke the agent for the specified thread for response
                async for response in agent.invoke(messages=user_input, thread=thread):
                    print(f"# {response.name}: {response}")
                    thread = response.thread
        finally:
            # Clean up resources.
            await thread.delete() if thread else None
            await client.agents.delete_vector_store(vector_store.id)
            await client.agents.delete_file(file.id)
            await client.agents.delete_agent(agent.id)
            print("\nCleaned up agent, thread, file, and vector store.")

await main()

# %% [markdown]
# You should see output similar to:
#
# ```
# # User: 'Can you explain Contoso's travel insurance coverage?'
# # Agent: Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage【4:0†document.md】.
# # User: 'What is a Neural Network?'
# # Agent: I'm sorry, but the uploaded document does not contain the necessary information to answer that question.
#
# Cleaned up agent, thread, file, and vector store.
# ```
